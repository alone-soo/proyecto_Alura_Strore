# %% [markdown]
# <a href="https://colab.research.google.com/github/alone-soo/proyecto_Alura_Strore/blob/main/AluraStoreLatamS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.sample(10)
# Out:
#                      Producto   Categoría del Producto     Precio  \
# 710              Celular ABXY             Electrónicos  1112300.0
# 1435                Impresora             Electrónicos   349400.0
# 1504             Refrigerador        Electrodomésticos  2409100.0
# 1668  Dashboards con Power BI                   Libros    31500.0
# 517           Cubo mágico 8x8                 Juguetes    19900.0
# 1277                 Smart TV             Electrónicos  1214600.0
# 545         Guitarra acústica   Instrumentos musicales   200800.0
# 985        Cuerda para saltar     Deportes y diversión    14800.0
# 1621            Mesa de noche                  Muebles   301000.0
# 289           Olla de presión  Artículos para el hogar    95600.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 710          57400.0      13/06/2020  Izabela de León          Bogotá
# 1435         16800.0      17/11/2021    Lucas Olivera            Cali
# ...

# %%
tienda2['Precio']
# Out:
# 0        283600.0
# 1         76800.0
# 2        443300.0
# 3        906200.0
# 4        397800.0
#           ...
# 2354     140300.0
# 2355    1220100.0
# 2356     797900.0
# 2357    2224300.0
# 2358     551000.0
# Name: Precio, Length: 2359, dtype: float64

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresot_t1 = tienda['Precio'].sum().astype(int)
ingresot_t2 = tienda2['Precio'].sum().astype(int)
ingresot_t3 = tienda3['Precio'].sum().astype(int)
ingresot_t4 = tienda4['Precio'].sum().astype(int)
ingreso_totales = [('Tienda 1', ingresot_t1), ('Tienda 2', ingresot_t2), ('Tienda 3', ingresot_t3), ('Tienda 4', ingresot_t4)]
ingreso_totales
# Out:
# [('Tienda 1', np.int64(1150880400)),
#  ('Tienda 2', np.int64(1116343500)),
#  ('Tienda 3', np.int64(1098019600)),
#  ('Tienda 4', np.int64(1038375700))]

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda2['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda3['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda4['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_t1 = tienda['Calificación'].mean()
calificacion_t2 = tienda2['Calificación'].mean()
calificacion_t3 = tienda3['Calificación'].mean()
calificacion_t4 = tienda4['Calificación'].mean()

# %%
calificacion_t3
# Out:
# np.float64(4.048325561678677)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productos_t1 = tienda['Producto'].value_counts().sort_values(ascending=False)
productos_t1.plot(kind='bar', figsize=(15,10), title='Productos más vendidos')
# Out:
# <Axes: title={'center': 'Productos más vendidos'}, xlabel='Producto'>

# %%
productos_t2 = tienda2['Producto'].value_counts().sort_values(ascending=False)
productos_t2.plot(kind='bar', figsize=(15,10), title='Productos más vendidos')
# Out:
# <Axes: title={'center': 'Productos más vendidos'}, xlabel='Producto'>

# %%
productos_t3 = tienda3['Producto'].value_counts().sort_values(ascending=False)
productos_t3.plot(kind='bar', figsize=(15,10), title='Productos más vendidos')
# Out:
# <Axes: title={'center': 'Productos más vendidos'}, xlabel='Producto'>

# %%
productos_t4 = tienda4['Producto'].value_counts().sort_values(ascending=False)
productos_t4.plot(kind='bar', figsize=(15,10), title='Productos más vendidos')
# Out:
# <Axes: title={'center': 'Productos más vendidos'}, xlabel='Producto'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
tienda['Costo de envío'].mean().astype(int)
# Out:
# np.int64(26018)

# %%
tienda2['Costo de envío'].mean().astype(int)
# Out:
# np.int64(25216)

# %%
tienda3['Costo de envío'].mean().astype(int)
# Out:
# np.int64(24805)

# %%
tienda4['Costo de envío'].mean().astype(int)
# Out:
# np.int64(23459)
