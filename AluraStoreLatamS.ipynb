# %% [markdown]
# <a href="https://colab.research.google.com/github/alone-soo/proyecto_Alura_Strore/blob/main/AluraStoreLatamS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.sample(10)
# Out:
#                        Producto   Categoría del Producto     Precio  \
# 1591         Cuerda para saltar     Deportes y diversión    25700.0
# 1421                 Cubertería  Artículos para el hogar    44600.0
# 2188               Refrigerador        Electrodomésticos  2519700.0
# 39                     Cama box                  Muebles   327200.0
# 1228  Iniciando en programación                   Libros    52500.0
# 1108          Guitarra acústica   Instrumentos musicales   200400.0
# 74                      Armario                  Muebles   490400.0
# 1530  Iniciando en programación                   Libros    59300.0
# 877                    Cama box                  Muebles   738000.0
# 70                      Mochila     Deportes y diversión   111000.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 1591          1600.0      02/11/2022      Pedro Gomez            Cali
# 1421             0.0      11/05/2022   Santiago Silva          Bogotá
# ...

# %%
tienda2['Precio']
# Out:
# 0        283600.0
# 1         76800.0
# 2        443300.0
# 3        906200.0
# 4        397800.0
#           ...
# 2354     140300.0
# 2355    1220100.0
# 2356     797900.0
# 2357    2224300.0
# 2358     551000.0
# Name: Precio, Length: 2359, dtype: float64

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresot_t1 = tienda['Precio'].sum().astype(int)
ingresot_t2 = tienda2['Precio'].sum().astype(int)
ingresot_t3 = tienda3['Precio'].sum().astype(int)
ingresot_t4 = tienda4['Precio'].sum().astype(int)

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
